# %%
import pandas as pd
import featuretools as ft
from woodwork.logical_types import Categorical

# %%
# let's load the data again

df = pd.read_csv("retail.csv", parse_dates=["invoice_date"])

# %%
# create and entity set

es = ft.EntitySet(id="data")

# %%
# Add the data to the entity

es = es.add_dataframe(
    dataframe=df,              # the dataframe with the data
    dataframe_name="data",     # unique name to associate with this dataframe
    index="rows",              # column name to index the items
    make_index=True,           # if true, create a new column with unique values
    time_index="invoice_date", # column containing time data
    logical_types={
        "customer_id": Categorical, # the id is numerical, but should be handled as categorical
    },
)

# %%
# Create a new dataframe with invoices
# indicating its relationship to the main data

es.normalize_dataframe(
    base_dataframe_name="data",     # Datarame name from which to split.
    new_dataframe_name="invoices",  # Name of the new dataframe.
    index="invoice",                # relationship will be created across this column.
    copy_columns=["customer_id"],   # columns to remove from base_dataframe and move to new dataframe.
)
# Out:
# Entityset: data
#   DataFrames:
#     data [Rows: 741301, Columns: 8]
#     invoices [Rows: 40505, Columns: 3]
#   Relationships:
#     data.invoice -> invoices.invoice

# %%
# cumulative transform primitives

cum_primitives = ["cum_sum", "cum_max", "diff", "time_since_previous"]

general_primitives = ["sine"]

# %%
# create all features simultaneously

feature_matrix, feature_defs = ft.dfs(
    entityset=es,                                # the entity set
    target_dataframe_name="data",                # the dataframe for wich to create the features
    agg_primitives=[],                           # empty list to avoid returning the defo parameters
    trans_primitives=general_primitives,         # empty list to avoid returning the defo parameters
    groupby_trans_primitives = cum_primitives,   # the operations to perform by invoice
    ignore_dataframes = ["invoices"],            # columns to ignore when creating features
)

# display name of created features
feature_defs
# Out:
# [<Feature: customer_id>,
#  <Feature: invoice>,
#  <Feature: stock_code>,
#  <Feature: description>,
#  <Feature: quantity>,
#  <Feature: price>,
#  <Feature: SINE(price)>,
#  <Feature: SINE(quantity)>,
#  <Feature: CUM_MAX(price) by invoice>,
#  <Feature: CUM_MAX(quantity) by invoice>,
#  <Feature: CUM_SUM(price) by invoice>,
#  <Feature: CUM_SUM(quantity) by invoice>,
#  <Feature: DIFF(price) by invoice>,
#  <Feature: DIFF(quantity) by invoice>,
#  <Feature: TIME_SINCE_PREVIOUS(invoice_date) by invoice>]

# %%
# Resulting datatable with original 
# and new features

feature_matrix.head()
# Out:
#      customer_id invoice stock_code                          description  \
# rows
# 0        13085.0  489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        13085.0  489434     79323P                   PINK CHERRY LIGHTS
# 2        13085.0  489434     79323W                  WHITE CHERRY LIGHTS
# 3        13085.0  489434      22041         RECORD FRAME 7" SINGLE SIZE
# 4        13085.0  489434      21232       STRAWBERRY CERAMIC TRINKET BOX
#
#       quantity  price  SINE(price)  SINE(quantity)  CUM_MAX(price) by invoice  \
# rows
# 0           12   6.95     0.618486       -0.536573                       6.95
# 1           12   6.75     0.450044       -0.536573                       6.95
# 2           12   6.75     0.450044       -0.536573                       6.95
# 3           48   2.10     0.863209       -0.768255                       6.95
# 4           24   1.25     0.948985       -0.905578                       6.95
#
#       CUM_MAX(quantity) by invoice  CUM_SUM(price) by invoice  \
# rows
# 0                             12.0                       6.95
# 1                             12.0                      13.70
# 2                             12.0                      20.45
# 3                             48.0                      22.55
# 4                             48.0                      23.80
#
#       CUM_SUM(quantity) by invoice  DIFF(price) by invoice  \
# rows
# 0                             12.0                     NaN
# 1                             24.0                   -0.20
# 2                             36.0                    0.00
# 3                             84.0                   -4.65
# 4                            108.0                   -0.85
#
#       DIFF(quantity) by invoice  TIME_SINCE_PREVIOUS(invoice_date) by invoice
# rows
# 0                           NaN                                           NaN
# 1                           0.0                                           0.0
# 2                           0.0                                           0.0
# 3                          36.0                                           0.0
# 4                         -24.0                                           0.0

# %%
# inspect values for 1 invoice

feature_matrix[feature_matrix["invoice"] == "489434"]
# Out:
#      customer_id invoice stock_code                          description  \
# rows
# 0        13085.0  489434      85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1        13085.0  489434     79323P                   PINK CHERRY LIGHTS
# 2        13085.0  489434     79323W                  WHITE CHERRY LIGHTS
# 3        13085.0  489434      22041         RECORD FRAME 7" SINGLE SIZE
# 4        13085.0  489434      21232       STRAWBERRY CERAMIC TRINKET BOX
# 5        13085.0  489434      22064           PINK DOUGHNUT TRINKET POT
# 6        13085.0  489434      21871                  SAVE THE PLANET MUG
# 7        13085.0  489434      21523   FANCY FONT HOME SWEET HOME DOORMAT
#
#       quantity  price  SINE(price)  SINE(quantity)  CUM_MAX(price) by invoice  \
# rows
# 0           12   6.95     0.618486       -0.536573                       6.95
# 1           12   6.75     0.450044       -0.536573                       6.95
# 2           12   6.75     0.450044       -0.536573                       6.95
# 3           48   2.10     0.863209       -0.768255                       6.95
# 4           24   1.25     0.948985       -0.905578                       6.95
# 5           24   1.65     0.996865       -0.905578                       6.95
# 6           24   1.25     0.948985       -0.905578                       6.95
# 7           10   5.95    -0.327055       -0.544021                       6.95
#
#       CUM_MAX(quantity) by invoice  CUM_SUM(price) by invoice  \
# rows
# 0                             12.0                       6.95
# 1                             12.0                      13.70
# 2                             12.0                      20.45
# 3                             48.0                      22.55
# 4                             48.0                      23.80
# 5                             48.0                      25.45
# 6                             48.0                      26.70
# 7                             48.0                      32.65
#
#       CUM_SUM(quantity) by invoice  DIFF(price) by invoice  \
# rows
# 0                             12.0                     NaN
# 1                             24.0                   -0.20
# 2                             36.0                    0.00
# 3                             84.0                   -4.65
# 4                            108.0                   -0.85
# 5                            132.0                    0.40
# 6                            156.0                   -0.40
# 7                            166.0                    4.70
#
#       DIFF(quantity) by invoice  TIME_SINCE_PREVIOUS(invoice_date) by invoice
# rows
# 0                           NaN                                           NaN
# 1                           0.0                                           0.0
# 2                           0.0                                           0.0
# 3                          36.0                                           0.0
# 4                         -24.0                                           0.0
# 5                           0.0                                           0.0
# 6                           0.0                                           0.0
# 7                         -14.0                                           0.0

# %%
# inspect values for another invoice

feature_matrix[feature_matrix["invoice"] == "489435"]
# Out:
#      customer_id invoice stock_code                         description  \
# rows
# 8        13085.0  489435      22350                           CAT BOWL
# 9        13085.0  489435      22349      DOG BOWL , CHASING BALL DESIGN
# 10       13085.0  489435      22195        HEART MEASURING SPOONS LARGE
# 11       13085.0  489435      22353  LUNCHBOX WITH CUTLERY FAIRY CAKES
#
#       quantity  price  SINE(price)  SINE(quantity)  CUM_MAX(price) by invoice  \
# rows
# 8           12   2.55     0.557684       -0.536573                       2.55
# 9           12   3.75    -0.571561       -0.536573                       3.75
# 10          24   1.65     0.996865       -0.905578                       3.75
# 11          12   2.55     0.557684       -0.536573                       3.75
#
#       CUM_MAX(quantity) by invoice  CUM_SUM(price) by invoice  \
# rows
# 8                             12.0                       2.55
# 9                             12.0                       6.30
# 10                            24.0                       7.95
# 11                            24.0                      10.50
#
#       CUM_SUM(quantity) by invoice  DIFF(price) by invoice  \
# rows
# 8                             12.0                     NaN
# 9                             24.0                     1.2
# 10                            48.0                    -2.1
# 11                            60.0                     0.9
#
#       DIFF(quantity) by invoice  TIME_SINCE_PREVIOUS(invoice_date) by invoice
# rows
# 8                           NaN                                           NaN
# 9                           0.0                                           0.0
# 10                         12.0                                           0.0
# 11                        -12.0                                           0.0

# %% [markdown]
# ## In relation to pandas

# %%
# load data

df = pd.read_csv("retail.csv", parse_dates=["invoice_date"])

df.head()
# Out:
#    customer_id invoice        invoice_date stock_code  \
# 0      13085.0  489434 2009-12-01 07:45:00      85048
# 1      13085.0  489434 2009-12-01 07:45:00     79323P
# 2      13085.0  489434 2009-12-01 07:45:00     79323W
# 3      13085.0  489434 2009-12-01 07:45:00      22041
# 4      13085.0  489434 2009-12-01 07:45:00      21232
#
#                            description  quantity  price
# 0  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12   6.95
# 1                   PINK CHERRY LIGHTS        12   6.75
# 2                  WHITE CHERRY LIGHTS        12   6.75
# 3         RECORD FRAME 7" SINGLE SIZE         48   2.10
# 4       STRAWBERRY CERAMIC TRINKET BOX        24   1.25

# %%
# Cumulative sum at invoice level

# numerical variables
numeric_vars = ["quantity", "price"]

# new variable names
new_names = [f"{var}_cumsum" for var in numeric_vars]

new_names
# Out:
# ['quantity_cumsum', 'price_cumsum']

# %%
# get cumulative sum
df[new_names] = df.groupby("invoice")[numeric_vars].cumsum()

# display input variables and new features
df[numeric_vars + new_names].head()
# Out:
#    quantity  price  quantity_cumsum  price_cumsum
# 0        12   6.95               12          6.95
# 1        12   6.75               24         13.70
# 2        12   6.75               36         20.45
# 3        48   2.10               84         22.55
# 4        24   1.25              108         23.80

# %%
# inspect values for 1 invoice

df[df["invoice"] == "489434" ][numeric_vars + new_names]
# Out:
#    quantity  price  quantity_cumsum  price_cumsum
# 0        12   6.95               12          6.95
# 1        12   6.75               24         13.70
# 2        12   6.75               36         20.45
# 3        48   2.10               84         22.55
# 4        24   1.25              108         23.80
# 5        24   1.65              132         25.45
# 6        24   1.25              156         26.70
# 7        10   5.95              166         32.65

# %%
# inspect values in a different invoice

df[df["invoice"] == "489435" ][numeric_vars + new_names]
# Out:
#     quantity  price  quantity_cumsum  price_cumsum
# 8         12   2.55               12          2.55
# 9         12   3.75               24          6.30
# 10        24   1.65               48          7.95
# 11        12   2.55               60         10.50

# %%
# Create features with multiple functions

# functions
func = ["cumsum", "cummax", "diff"]

# new variable names
new_names = [f"{var}_{function}" for function in func for var in numeric_vars]

new_names
# Out:
# ['quantity_cumsum',
#  'price_cumsum',
#  'quantity_cummax',
#  'price_cummax',
#  'quantity_diff',
#  'price_diff']

# %%
df[new_names] = df.groupby("invoice")[numeric_vars].agg(func)

df[new_names].head()
# Out:
#    quantity_cumsum  price_cumsum  quantity_cummax  price_cummax  \
# 0               12            12              NaN          6.95
# 1               24            12              0.0         13.70
# 2               36            12              0.0         20.45
# 3               84            48             36.0         22.55
# 4              108            48            -24.0         23.80
#
#    quantity_diff  price_diff
# 0           6.95         NaN
# 1           6.95       -0.20
# 2           6.95        0.00
# 3           6.95       -4.65
# 4           6.95       -0.85

# %%
# general transformations

new_names = [f"{var}_{function}" for function in ["sin", "cos"] for var in numeric_vars]

new_names
# Out:
# ['quantity_sin', 'price_sin', 'quantity_cos', 'price_cos']

# %%
import numpy as np

# %%
df[new_names] = df[numeric_vars].agg([np.sin, np.cos])

df[new_names].head()
# Out:
#    quantity_sin  price_sin  quantity_cos  price_cos
# 0     -0.536573   0.843854      0.618486   0.785796
# 1     -0.536573   0.843854      0.450044   0.893006
# 2     -0.536573   0.843854      0.450044   0.893006
# 3     -0.768255  -0.640144      0.863209  -0.504846
# 4     -0.905578   0.424179      0.948985   0.315322
